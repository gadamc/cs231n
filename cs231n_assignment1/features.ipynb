# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 20 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

#learning_rates = [1e-9, 1e-8, 1e-7]
#regularization_strengths = [5e4, 5e5, 5e6]

learning_rates = [10**np.random.uniform(-3, -1) for i in xrange(5)]
regularization_strengths = [10**np.random.uniform(-8, -6) for i in xrange(5)]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
acc = lambda v, v_pred: np.mean(v == v_pred)

for lr in learning_rates:
    for k in regularization_strengths:
        print("lr " + str(lr))
        print("reg " + str(k))
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=k, num_iters=1000)
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        trainbest = acc(y_train, y_train_pred)
        valbest = acc(y_val, y_val_pred)
        print("training accuracy %f" %trainbest)
        print("val accuracy %f" %valbest)
        if valbest > best_val:
            best_val = valbest
            best_svm = svm
        results[(lr, k)] = (trainbest, valbest)
        
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 0.00468868116386971
# reg 1.54552156365877e-07
# training accuracy 0.512531
# val accuracy 0.506000
# lr 0.00468868116386971
# reg 3.3547423972815653e-07
# training accuracy 0.513857
# val accuracy 0.508000
# lr 0.00468868116386971
# reg 8.247652998669749e-08
# training accuracy 0.514531
# val accuracy 0.508000
# lr 0.00468868116386971
# reg 3.055720442994002e-07
# training accuracy 0.512653
# val accuracy 0.518000
# lr 0.00468868116386971
# reg 5.755308515337425e-08
# training accuracy 0.514327
# val accuracy 0.509000
# lr 0.0534570929579159
# reg 1.54552156365877e-07
# training accuracy 0.502000
# val accuracy 0.492000
# lr 0.0534570929579159
# reg 3.3547423972815653e-07
# training accuracy 0.502020
# val accuracy 0.490000
# lr 0.0534570929579159
# reg 8.247652998669749e-08
# training accuracy 0.497388
# val accuracy 0.489000
# lr 0.0534570929579159
# reg 3.055720442994002e-07
# training accuracy 0.497102
# val accuracy 0.486000
# lr 0.0534570929579159
# reg 5.755308515337425e-08
# training accuracy 0.503265
# val accuracy 0.501000
# lr 0.049791882827503964
# reg 1.54552156365877e-07
# training accuracy 0.501327
# val accuracy 0.497000
# lr 0.049791882827503964
# reg 3.3547423972815653e-07
# training accuracy 0.504102
# val accuracy 0.487000
# lr 0.049791882827503964
# reg 8.247652998669749e-08
# training accuracy 0.501735
# val accuracy 0.502000
# lr 0.049791882827503964
# reg 3.055720442994002e-07
# training accuracy 0.501939
# val accuracy 0.504000
# lr 0.049791882827503964
# reg 5.755308515337425e-08
# training accuracy 0.503000
# val accuracy 0.486000
# lr 0.044192984671772205
# reg 1.54552156365877e-07
# training accuracy 0.501429
# val accuracy 0.487000
# lr 0.044192984671772205
# reg 3.3547423972815653e-07
# training accuracy 0.501041
# val accuracy 0.499000
# lr 0.044192984671772205
# reg 8.247652998669749e-08
# training accuracy 0.501408
# val accuracy 0.505000
# lr 0.044192984671772205
# reg 3.055720442994002e-07
# training accuracy 0.503837
# val accuracy 0.491000
# lr 0.044192984671772205
# reg 5.755308515337425e-08
# training accuracy 0.500673
# val accuracy 0.493000
# lr 0.09079708603315675
# reg 1.54552156365877e-07
# training accuracy 0.489449
# val accuracy 0.481000
# lr 0.09079708603315675
# reg 3.3547423972815653e-07
# training accuracy 0.490469
# val accuracy 0.487000
# lr 0.09079708603315675
# reg 8.247652998669749e-08
# training accuracy 0.490327
# val accuracy 0.482000
# lr 0.09079708603315675
# reg 3.055720442994002e-07
# training accuracy 0.491469
# val accuracy 0.479000
# lr 0.09079708603315675
# reg 5.755308515337425e-08
# training accuracy 0.487939
# val accuracy 0.479000
# lr 4.688681e-03 reg 5.755309e-08 train accuracy: 0.514327 val accuracy: 0.509000
# lr 4.688681e-03 reg 8.247653e-08 train accuracy: 0.514531 val accuracy: 0.508000
# lr 4.688681e-03 reg 1.545522e-07 train accuracy: 0.512531 val accuracy: 0.506000
# lr 4.688681e-03 reg 3.055720e-07 train accuracy: 0.512653 val accuracy: 0.518000
# lr 4.688681e-03 reg 3.354742e-07 train accuracy: 0.513857 val accuracy: 0.508000
# lr 4.419298e-02 reg 5.755309e-08 train accuracy: 0.500673 val accuracy: 0.493000
# lr 4.419298e-02 reg 8.247653e-08 train accuracy: 0.501408 val accuracy: 0.505000
# lr 4.419298e-02 reg 1.545522e-07 train accuracy: 0.501429 val accuracy: 0.487000
# lr 4.419298e-02 reg 3.055720e-07 train accuracy: 0.503837 val accuracy: 0.491000
# lr 4.419298e-02 reg 3.354742e-07 train accuracy: 0.501041 val accuracy: 0.499000
# lr 4.979188e-02 reg 5.755309e-08 train accuracy: 0.503000 val accuracy: 0.486000
# lr 4.979188e-02 reg 8.247653e-08 train accuracy: 0.501735 val accuracy: 0.502000
# lr 4.979188e-02 reg 1.545522e-07 train accuracy: 0.501327 val accuracy: 0.497000
# lr 4.979188e-02 reg 3.055720e-07 train accuracy: 0.501939 val accuracy: 0.504000
# lr 4.979188e-02 reg 3.354742e-07 train accuracy: 0.504102 val accuracy: 0.487000
# lr 5.345709e-02 reg 5.755309e-08 train accuracy: 0.503265 val accuracy: 0.501000
# lr 5.345709e-02 reg 8.247653e-08 train accuracy: 0.497388 val accuracy: 0.489000
# lr 5.345709e-02 reg 1.545522e-07 train accuracy: 0.502000 val accuracy: 0.492000
# lr 5.345709e-02 reg 3.055720e-07 train accuracy: 0.497102 val accuracy: 0.486000
# lr 5.345709e-02 reg 3.354742e-07 train accuracy: 0.502020 val accuracy: 0.490000
# lr 9.079709e-02 reg 5.755309e-08 train accuracy: 0.487939 val accuracy: 0.479000
# lr 9.079709e-02 reg 8.247653e-08 train accuracy: 0.490327 val accuracy: 0.482000
# lr 9.079709e-02 reg 1.545522e-07 train accuracy: 0.489449 val accuracy: 0.481000
# lr 9.079709e-02 reg 3.055720e-07 train accuracy: 0.491469 val accuracy: 0.479000
# lr 9.079709e-02 reg 3.354742e-07 train accuracy: 0.490469 val accuracy: 0.487000
# best validation accuracy achieved during cross-validation: 0.518000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.491

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 165)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
num_classes = 10

best_net = None

#learning_rates = [1e-9, 1e-8, 1e-7]
#regularization_strengths = [5e5, 1e6, 5e6, 5e7, 5e8]
#hidden_size = [500]
learning_rates = [1e-9, 1e-8, 1e-7, 2e-6, 5e-4]
regularization_strengths = [1e5, 1e6, 1e7, 1e8, 2e7, 3e3]

learning_rates = [np.random.uniform() for i in xrange(5)]
regularization_strengths = [10**np.random.uniform(-6, -7) for i in xrange(5)]
regularization_strengths.append(0)
#learning_rates = [1e-1, 5e-2, 1e-2]
#regularization_strengths = [0.5, 1.0, 5.0, 10.0, 100.0, 1e4, 1e6, 1e8]
hidden_size = [500]

results = {}

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
acc = lambda v, v_pred: np.mean(v == v_pred)

for lr in learning_rates:
    for k in regularization_strengths:
        for h in hidden_size:
            print("lr " + str(lr))
            print("reg " + str(k))
            print("L_hidden " + str(h))
            
            net = TwoLayerNet(input_dim, h, num_classes)
            net.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=1000, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=k, verbose=True)
            y_train_pred = net.predict(X_train_feats)
            y_val_pred = net.predict(X_val_feats)
            trainbest = acc(y_train, y_train_pred)
            valbest = acc(y_val, y_val_pred)
            print("training accuracy %f" %trainbest)
            print("val accuracy %f" %valbest)
            if valbest > best_val:
                best_val = valbest
                best_net = net
            results[(lr, k)] = (trainbest, valbest)
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# lr 0.9603891701058277
# reg 1.5894575787294286e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.503097
# iteration 200 / 1000: loss 1.189478
# iteration 300 / 1000: loss 1.197647
# iteration 400 / 1000: loss 1.078966
# iteration 500 / 1000: loss 1.022445
# iteration 600 / 1000: loss 1.053731
# iteration 700 / 1000: loss 1.021365
# iteration 800 / 1000: loss 1.035466
# iteration 900 / 1000: loss 1.021503
# training accuracy 0.682347
# val accuracy 0.546000
# lr 0.9603891701058277
# reg 7.703654933587518e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.531675
# iteration 200 / 1000: loss 1.323230
# iteration 300 / 1000: loss 1.135024
# iteration 400 / 1000: loss 1.316101
# iteration 500 / 1000: loss 1.106617
# iteration 600 / 1000: loss 1.159540
# iteration 700 / 1000: loss 1.069468
# iteration 800 / 1000: loss 1.163559
# iteration 900 / 1000: loss 0.893180
# training accuracy 0.685816
# val accuracy 0.578000
# lr 0.9603891701058277
# reg 3.5800555526806553e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.429739
# iteration 200 / 1000: loss 1.483403
# iteration 300 / 1000: loss 1.082760
# iteration 400 / 1000: loss 1.196796
# iteration 500 / 1000: loss 1.201069
# iteration 600 / 1000: loss 0.958311
# iteration 700 / 1000: loss 0.992956
# iteration 800 / 1000: loss 0.949334
# iteration 900 / 1000: loss 0.968526
# training accuracy 0.685408
# val accuracy 0.582000
# lr 0.9603891701058277
# reg 3.0079200767736665e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.595178
# iteration 200 / 1000: loss 1.329668
# iteration 300 / 1000: loss 1.152410
# iteration 400 / 1000: loss 1.138685
# iteration 500 / 1000: loss 1.210685
# iteration 600 / 1000: loss 1.069947
# iteration 700 / 1000: loss 1.108318
# iteration 800 / 1000: loss 0.989490
# iteration 900 / 1000: loss 1.107572
# training accuracy 0.687776
# val accuracy 0.574000
# lr 0.9603891701058277
# reg 3.0842496290050016e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.468464
# iteration 200 / 1000: loss 1.318894
# iteration 300 / 1000: loss 1.316989
# iteration 400 / 1000: loss 1.116850
# iteration 500 / 1000: loss 1.126883
# iteration 600 / 1000: loss 1.050510
# iteration 700 / 1000: loss 0.920753
# iteration 800 / 1000: loss 0.983138
# iteration 900 / 1000: loss 0.947191
# training accuracy 0.688612
# val accuracy 0.574000
# lr 0.9603891701058277
# reg 0
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.405465
# iteration 200 / 1000: loss 1.255285
# iteration 300 / 1000: loss 1.268232
# iteration 400 / 1000: loss 1.241195
# iteration 500 / 1000: loss 1.173136
# iteration 600 / 1000: loss 1.039631
# iteration 700 / 1000: loss 1.098495
# iteration 800 / 1000: loss 0.974697
# iteration 900 / 1000: loss 0.974903
# training accuracy 0.686000
# val accuracy 0.572000
# lr 0.2207340430471635
# reg 1.5894575787294286e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.989057
# iteration 200 / 1000: loss 1.545356
# iteration 300 / 1000: loss 1.431113
# iteration 400 / 1000: loss 1.322527
# iteration 500 / 1000: loss 1.353984
# iteration 600 / 1000: loss 1.280444
# iteration 700 / 1000: loss 1.468678
# iteration 800 / 1000: loss 1.222504
# iteration 900 / 1000: loss 1.191776
# training accuracy 0.569531
# val accuracy 0.555000
# lr 0.2207340430471635
# reg 7.703654933587518e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.964287
# iteration 200 / 1000: loss 1.564497
# iteration 300 / 1000: loss 1.327032
# iteration 400 / 1000: loss 1.363207
# iteration 500 / 1000: loss 1.456720
# iteration 600 / 1000: loss 1.474089
# iteration 700 / 1000: loss 1.246202
# iteration 800 / 1000: loss 1.280453
# iteration 900 / 1000: loss 1.104668
# training accuracy 0.572694
# val accuracy 0.556000
# lr 0.2207340430471635
# reg 3.5800555526806553e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.000126
# iteration 200 / 1000: loss 1.553219
# iteration 300 / 1000: loss 1.409230
# iteration 400 / 1000: loss 1.370887
# iteration 500 / 1000: loss 1.304055
# iteration 600 / 1000: loss 1.311581
# iteration 700 / 1000: loss 1.346574
# iteration 800 / 1000: loss 1.322679
# iteration 900 / 1000: loss 1.151143
# training accuracy 0.568020
# val accuracy 0.539000
# lr 0.2207340430471635
# reg 3.0079200767736665e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.054313
# iteration 200 / 1000: loss 1.570470
# iteration 300 / 1000: loss 1.366362
# iteration 400 / 1000: loss 1.391799
# iteration 500 / 1000: loss 1.340053
# iteration 600 / 1000: loss 1.355628
# iteration 700 / 1000: loss 1.311104
# iteration 800 / 1000: loss 1.166682
# iteration 900 / 1000: loss 1.361046
# training accuracy 0.573020
# val accuracy 0.553000
# lr 0.2207340430471635
# reg 3.0842496290050016e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.033438
# iteration 200 / 1000: loss 1.508219
# iteration 300 / 1000: loss 1.258617
# iteration 400 / 1000: loss 1.410556
# iteration 500 / 1000: loss 1.361371
# iteration 600 / 1000: loss 1.273034
# iteration 700 / 1000: loss 1.475671
# iteration 800 / 1000: loss 1.248837
# iteration 900 / 1000: loss 1.207624
# training accuracy 0.570082
# val accuracy 0.538000
# lr 0.2207340430471635
# reg 0
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.968108
# iteration 200 / 1000: loss 1.480145
# iteration 300 / 1000: loss 1.383643
# iteration 400 / 1000: loss 1.391471
# iteration 500 / 1000: loss 1.398680
# iteration 600 / 1000: loss 1.293131
# iteration 700 / 1000: loss 1.322143
# iteration 800 / 1000: loss 1.348238
# iteration 900 / 1000: loss 1.238489
# training accuracy 0.572000
# val accuracy 0.544000
# lr 0.5205630304077332
# reg 1.5894575787294286e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.410987
# iteration 200 / 1000: loss 1.293393
# iteration 300 / 1000: loss 1.268322
# iteration 400 / 1000: loss 1.205907
# iteration 500 / 1000: loss 1.180713
# iteration 600 / 1000: loss 1.192033
# iteration 700 / 1000: loss 1.051556
# iteration 800 / 1000: loss 1.038843
# iteration 900 / 1000: loss 0.931153
# training accuracy 0.640469
# val accuracy 0.561000
# lr 0.5205630304077332
# reg 7.703654933587518e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.492183
# iteration 200 / 1000: loss 1.427081
# iteration 300 / 1000: loss 1.292548
# iteration 400 / 1000: loss 1.178327
# iteration 500 / 1000: loss 1.238777
# iteration 600 / 1000: loss 1.010320
# iteration 700 / 1000: loss 1.223477
# iteration 800 / 1000: loss 1.080634
# iteration 900 / 1000: loss 1.146127
# training accuracy 0.648347
# val accuracy 0.575000
# lr 0.5205630304077332
# reg 3.5800555526806553e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.419147
# iteration 200 / 1000: loss 1.266044
# iteration 300 / 1000: loss 1.322682
# iteration 400 / 1000: loss 1.259644
# iteration 500 / 1000: loss 1.251587
# iteration 600 / 1000: loss 1.213922
# iteration 700 / 1000: loss 1.174820
# iteration 800 / 1000: loss 1.117682
# iteration 900 / 1000: loss 0.997395
# training accuracy 0.647020
# val accuracy 0.580000
# lr 0.5205630304077332
# reg 3.0079200767736665e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.644345
# iteration 200 / 1000: loss 1.394863
# iteration 300 / 1000: loss 1.240746
# iteration 400 / 1000: loss 1.335010
# iteration 500 / 1000: loss 1.079472
# iteration 600 / 1000: loss 1.311727
# iteration 700 / 1000: loss 1.145619
# iteration 800 / 1000: loss 1.007183
# iteration 900 / 1000: loss 1.029986
# training accuracy 0.646551
# val accuracy 0.575000
# lr 0.5205630304077332
# reg 3.0842496290050016e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.456549
# iteration 200 / 1000: loss 1.386271
# iteration 300 / 1000: loss 1.421046
# iteration 400 / 1000: loss 1.172281
# iteration 500 / 1000: loss 1.291534
# iteration 600 / 1000: loss 1.091909
# iteration 700 / 1000: loss 1.141766
# iteration 800 / 1000: loss 1.027883
# iteration 900 / 1000: loss 1.146983
# training accuracy 0.651347
# val accuracy 0.563000
# lr 0.5205630304077332
# reg 0
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.468976
# iteration 200 / 1000: loss 1.520705
# iteration 300 / 1000: loss 1.415395
# iteration 400 / 1000: loss 1.200692
# iteration 500 / 1000: loss 1.221758
# iteration 600 / 1000: loss 1.217522
# iteration 700 / 1000: loss 1.224609
# iteration 800 / 1000: loss 1.136055
# iteration 900 / 1000: loss 1.067445
# training accuracy 0.638061
# val accuracy 0.572000
# lr 0.34570831260544466
# reg 1.5894575787294286e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.661277
# iteration 200 / 1000: loss 1.334410
# iteration 300 / 1000: loss 1.484190
# iteration 400 / 1000: loss 1.161482
# iteration 500 / 1000: loss 1.242349
# iteration 600 / 1000: loss 1.119103
# iteration 700 / 1000: loss 1.097436
# iteration 800 / 1000: loss 1.210973
# iteration 900 / 1000: loss 1.093467
# training accuracy 0.615449
# val accuracy 0.578000
# lr 0.34570831260544466
# reg 7.703654933587518e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.684335
# iteration 200 / 1000: loss 1.409575
# iteration 300 / 1000: loss 1.275769
# iteration 400 / 1000: loss 1.272047
# iteration 500 / 1000: loss 1.269117
# iteration 600 / 1000: loss 1.201337
# iteration 700 / 1000: loss 1.246864
# iteration 800 / 1000: loss 1.103999
# iteration 900 / 1000: loss 1.144380
# training accuracy 0.612816
# val accuracy 0.573000
# lr 0.34570831260544466
# reg 3.5800555526806553e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.690048
# iteration 200 / 1000: loss 1.453565
# iteration 300 / 1000: loss 1.482373
# iteration 400 / 1000: loss 1.346175
# iteration 500 / 1000: loss 1.205340
# iteration 600 / 1000: loss 1.264878
# iteration 700 / 1000: loss 1.271793
# iteration 800 / 1000: loss 1.134651
# iteration 900 / 1000: loss 1.050511
# training accuracy 0.611776
# val accuracy 0.575000
# lr 0.34570831260544466
# reg 3.0079200767736665e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.736932
# iteration 200 / 1000: loss 1.307838
# iteration 300 / 1000: loss 1.400738
# iteration 400 / 1000: loss 1.260501
# iteration 500 / 1000: loss 1.337896
# iteration 600 / 1000: loss 1.225144
# iteration 700 / 1000: loss 1.145634
# iteration 800 / 1000: loss 1.135361
# iteration 900 / 1000: loss 1.061286
# training accuracy 0.608673
# val accuracy 0.564000
# lr 0.34570831260544466
# reg 3.0842496290050016e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.744580
# iteration 200 / 1000: loss 1.273741
# iteration 300 / 1000: loss 1.247879
# iteration 400 / 1000: loss 1.400328
# iteration 500 / 1000: loss 1.298011
# iteration 600 / 1000: loss 1.208973
# iteration 700 / 1000: loss 1.084004
# iteration 800 / 1000: loss 1.192696
# iteration 900 / 1000: loss 1.095007
# training accuracy 0.613408
# val accuracy 0.568000
# lr 0.34570831260544466
# reg 0
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.670427
# iteration 200 / 1000: loss 1.630172
# iteration 300 / 1000: loss 1.371064
# iteration 400 / 1000: loss 1.272326
# iteration 500 / 1000: loss 1.510239
# iteration 600 / 1000: loss 1.376213
# iteration 700 / 1000: loss 1.194996
# iteration 800 / 1000: loss 1.168760
# iteration 900 / 1000: loss 1.024165
# training accuracy 0.610776
# val accuracy 0.592000
# lr 0.15555088000990136
# reg 1.5894575787294286e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.262008
# iteration 200 / 1000: loss 1.727283
# iteration 300 / 1000: loss 1.482739
# iteration 400 / 1000: loss 1.325264
# iteration 500 / 1000: loss 1.535811
# iteration 600 / 1000: loss 1.272333
# iteration 700 / 1000: loss 1.265596
# iteration 800 / 1000: loss 1.336271
# iteration 900 / 1000: loss 1.336126
# training accuracy 0.543469
# val accuracy 0.523000
# lr 0.15555088000990136
# reg 7.703654933587518e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.257246
# iteration 200 / 1000: loss 1.774804
# iteration 300 / 1000: loss 1.486513
# iteration 400 / 1000: loss 1.377405
# iteration 500 / 1000: loss 1.364766
# iteration 600 / 1000: loss 1.405583
# iteration 700 / 1000: loss 1.216927
# iteration 800 / 1000: loss 1.240329
# iteration 900 / 1000: loss 1.288034
# training accuracy 0.550388
# val accuracy 0.530000
# lr 0.15555088000990136
# reg 3.5800555526806553e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.275361
# iteration 200 / 1000: loss 1.765245
# iteration 300 / 1000: loss 1.391746
# iteration 400 / 1000: loss 1.605579
# iteration 500 / 1000: loss 1.426609
# iteration 600 / 1000: loss 1.334391
# iteration 700 / 1000: loss 1.230529
# iteration 800 / 1000: loss 1.325224
# iteration 900 / 1000: loss 1.391393
# training accuracy 0.548020
# val accuracy 0.534000
# lr 0.15555088000990136
# reg 3.0079200767736665e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.276586
# iteration 200 / 1000: loss 1.724666
# iteration 300 / 1000: loss 1.550557
# iteration 400 / 1000: loss 1.499615
# iteration 500 / 1000: loss 1.463987
# iteration 600 / 1000: loss 1.364722
# iteration 700 / 1000: loss 1.391668
# iteration 800 / 1000: loss 1.390438
# iteration 900 / 1000: loss 1.346880
# training accuracy 0.548878
# val accuracy 0.528000
# lr 0.15555088000990136
# reg 3.0842496290050016e-07
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.275374
# iteration 200 / 1000: loss 1.752855
# iteration 300 / 1000: loss 1.493131
# iteration 400 / 1000: loss 1.373488
# iteration 500 / 1000: loss 1.317333
# iteration 600 / 1000: loss 1.354057
# iteration 700 / 1000: loss 1.363630
# iteration 800 / 1000: loss 1.344493
# iteration 900 / 1000: loss 1.195839
# training accuracy 0.548918
# val accuracy 0.539000
# lr 0.15555088000990136
# reg 0
# L_hidden 500
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.265828
# iteration 200 / 1000: loss 1.710913
# iteration 300 / 1000: loss 1.520851
# iteration 400 / 1000: loss 1.499075
# iteration 500 / 1000: loss 1.505054
# iteration 600 / 1000: loss 1.446452
# iteration 700 / 1000: loss 1.320441
# iteration 800 / 1000: loss 1.197585
# iteration 900 / 1000: loss 1.127302
# training accuracy 0.550429
# val accuracy 0.547000
# lr 1.555509e-01 reg 0.000000e+00 train accuracy: 0.550429 val accuracy: 0.547000
# lr 1.555509e-01 reg 1.589458e-07 train accuracy: 0.543469 val accuracy: 0.523000
# lr 1.555509e-01 reg 3.007920e-07 train accuracy: 0.548878 val accuracy: 0.528000
# lr 1.555509e-01 reg 3.084250e-07 train accuracy: 0.548918 val accuracy: 0.539000
# lr 1.555509e-01 reg 3.580056e-07 train accuracy: 0.548020 val accuracy: 0.534000
# lr 1.555509e-01 reg 7.703655e-07 train accuracy: 0.550388 val accuracy: 0.530000
# lr 2.207340e-01 reg 0.000000e+00 train accuracy: 0.572000 val accuracy: 0.544000
# lr 2.207340e-01 reg 1.589458e-07 train accuracy: 0.569531 val accuracy: 0.555000
# lr 2.207340e-01 reg 3.007920e-07 train accuracy: 0.573020 val accuracy: 0.553000
# lr 2.207340e-01 reg 3.084250e-07 train accuracy: 0.570082 val accuracy: 0.538000
# lr 2.207340e-01 reg 3.580056e-07 train accuracy: 0.568020 val accuracy: 0.539000
# lr 2.207340e-01 reg 7.703655e-07 train accuracy: 0.572694 val accuracy: 0.556000
# lr 3.457083e-01 reg 0.000000e+00 train accuracy: 0.610776 val accuracy: 0.592000
# lr 3.457083e-01 reg 1.589458e-07 train accuracy: 0.615449 val accuracy: 0.578000
# lr 3.457083e-01 reg 3.007920e-07 train accuracy: 0.608673 val accuracy: 0.564000
# lr 3.457083e-01 reg 3.084250e-07 train accuracy: 0.613408 val accuracy: 0.568000
# lr 3.457083e-01 reg 3.580056e-07 train accuracy: 0.611776 val accuracy: 0.575000
# lr 3.457083e-01 reg 7.703655e-07 train accuracy: 0.612816 val accuracy: 0.573000
# lr 5.205630e-01 reg 0.000000e+00 train accuracy: 0.638061 val accuracy: 0.572000
# lr 5.205630e-01 reg 1.589458e-07 train accuracy: 0.640469 val accuracy: 0.561000
# lr 5.205630e-01 reg 3.007920e-07 train accuracy: 0.646551 val accuracy: 0.575000
# lr 5.205630e-01 reg 3.084250e-07 train accuracy: 0.651347 val accuracy: 0.563000
# lr 5.205630e-01 reg 3.580056e-07 train accuracy: 0.647020 val accuracy: 0.580000
# lr 5.205630e-01 reg 7.703655e-07 train accuracy: 0.648347 val accuracy: 0.575000
# lr 9.603892e-01 reg 0.000000e+00 train accuracy: 0.686000 val accuracy: 0.572000
# lr 9.603892e-01 reg 1.589458e-07 train accuracy: 0.682347 val accuracy: 0.546000
# lr 9.603892e-01 reg 3.007920e-07 train accuracy: 0.687776 val accuracy: 0.574000
# lr 9.603892e-01 reg 3.084250e-07 train accuracy: 0.688612 val accuracy: 0.574000
# lr 9.603892e-01 reg 3.580056e-07 train accuracy: 0.685408 val accuracy: 0.582000
# lr 9.603892e-01 reg 7.703655e-07 train accuracy: 0.685816 val accuracy: 0.578000
# best validation accuracy achieved during cross-validation: 0.592000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.518

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
